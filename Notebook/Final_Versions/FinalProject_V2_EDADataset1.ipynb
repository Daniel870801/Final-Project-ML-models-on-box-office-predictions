# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_json('/Users/helmichaaba/Downloads/box_office_2010s.json')

# %%
df
# Out:
#       year rank                               title  total_sales     id  \
# 0     2012   64               Niko le petit Renne 2       787427  13130
# 1     2010  120                   Fantastic Mr. Fox       357881  10633
# 2     2014  103                                 Her       448841  13728
# 3     2010  145           AO, le dernier Néandertal       248610  11312
# 4     2012  150                  Le Fils de l'autre       251239  12635
# ...    ...  ...                                 ...          ...    ...
# 3954  2017   18                          La La Land      2746019  16448
# 3955  2017   17                              Cars 3      2766647  16452
# 3956  2017   16  La Planète des Singes - Suprématie      2883962  15748
# 3957  2017   15                  Le Sens de la fête      3020694  17386
# 3958  2017    7                    Fast & Furious 8      3838447  15184
#
#      release_date  max_theaters_used  first_screening_sales  first_day_sales  \
# ...

# %%
df.shape
# Out:
# (3959, 11)

# %%
df.describe()
# Out:
#               year   total_sales            id  max_theaters_used  \
# count  3959.000000  3.959000e+03   3959.000000        3959.000000
# mean   2014.638040  4.917572e+05  15024.960849         238.967921
# std       2.843053  9.748597e+05   2574.012114         213.411191
# min    2010.000000  3.500000e+01    299.000000           0.000000
# 25%    2012.000000  4.838300e+04  12856.500000          65.000000
# 50%    2015.000000  1.450690e+05  14941.000000         178.000000
# 75%    2017.000000  4.791780e+05  17226.500000         353.500000
# max    2019.000000  1.949069e+07  21624.000000        1205.000000
#
#        first_screening_sales  first_day_sales  first_weekend_sales  \
# count              43.000000      3807.000000         3.785000e+03
# mean             3933.651163     33386.873916         1.525431e+05
# std              7836.266038     66969.312329         2.722984e+05
# min                 2.000000         1.000000         3.600000e+01
# ...

# %%
df.dtypes
# Out:
# year                       int64
# rank                      object
# title                     object
# total_sales                int64
# id                         int64
# release_date              object
# max_theaters_used          int64
# first_screening_sales    float64
# first_day_sales          float64
# first_weekend_sales      float64
# first_week_sales           int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# year                        0
# rank                        0
# title                       0
# total_sales                 0
# id                          0
# release_date                0
# max_theaters_used           0
# first_screening_sales    3916
# first_day_sales           152
# first_weekend_sales       174
# first_week_sales            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['year', 'rank', 'title', 'total_sales', 'id', 'release_date',
#        'max_theaters_used', 'first_screening_sales', 'first_day_sales',
#        'first_weekend_sales', 'first_week_sales'],
#       dtype='object')

# %%
df.drop(['first_screening_sales'], axis=1, inplace=True)

# %%
df
# Out:
#       year rank                               title  total_sales     id  \
# 0     2012   64               Niko le petit Renne 2       787427  13130
# 1     2010  120                   Fantastic Mr. Fox       357881  10633
# 2     2014  103                                 Her       448841  13728
# 3     2010  145           AO, le dernier Néandertal       248610  11312
# 4     2012  150                  Le Fils de l'autre       251239  12635
# ...    ...  ...                                 ...          ...    ...
# 3954  2017   18                          La La Land      2746019  16448
# 3955  2017   17                              Cars 3      2766647  16452
# 3956  2017   16  La Planète des Singes - Suprématie      2883962  15748
# 3957  2017   15                  Le Sens de la fête      3020694  17386
# 3958  2017    7                    Fast & Furious 8      3838447  15184
#
#      release_date  max_theaters_used  first_day_sales  first_weekend_sales  \
# ...

# %%
df.dtypes
# Out:
# year                     int64
# rank                    object
# title                   object
# total_sales              int64
# id                       int64
# release_date            object
# max_theaters_used        int64
# first_day_sales        float64
# first_weekend_sales    float64
# first_week_sales         int64
# dtype: object

# %%
x=df.loc[df['release_date']!="2000-00-00"]

# %%
x
# Out:
#       year rank                               title  total_sales     id  \
# 0     2012   64               Niko le petit Renne 2       787427  13130
# 1     2010  120                   Fantastic Mr. Fox       357881  10633
# 2     2014  103                                 Her       448841  13728
# 3     2010  145           AO, le dernier Néandertal       248610  11312
# 4     2012  150                  Le Fils de l'autre       251239  12635
# ...    ...  ...                                 ...          ...    ...
# 3954  2017   18                          La La Land      2746019  16448
# 3955  2017   17                              Cars 3      2766647  16452
# 3956  2017   16  La Planète des Singes - Suprématie      2883962  15748
# 3957  2017   15                  Le Sens de la fête      3020694  17386
# 3958  2017    7                    Fast & Furious 8      3838447  15184
#
#      release_date  max_theaters_used  first_day_sales  first_weekend_sales  \
# ...

# %%
x['release_date']= pd.to_datetime(x['release_date'],format = '%Y-%m-%d')

# %%
x.dtypes
# Out:
# year                            int64
# rank                           object
# title                          object
# total_sales                     int64
# id                              int64
# release_date           datetime64[ns]
# max_theaters_used               int64
# first_day_sales               float64
# first_weekend_sales           float64
# first_week_sales                int64
# dtype: object

# %%
x['release_date'].unique()
# Out:
# array(['2012-11-28T00:00:00.000000000', '2010-02-17T00:00:00.000000000',
#        '2014-03-19T00:00:00.000000000', '2010-09-29T00:00:00.000000000',
#        '2012-04-04T00:00:00.000000000', '2012-10-17T00:00:00.000000000',
#        '2012-12-12T00:00:00.000000000', '2012-09-05T00:00:00.000000000',
#        '2012-08-29T00:00:00.000000000', '2012-04-11T00:00:00.000000000',
#        '2012-06-20T00:00:00.000000000', '2012-06-27T00:00:00.000000000',
#        '2012-02-15T00:00:00.000000000', '2012-02-22T00:00:00.000000000',
#        '2012-01-04T00:00:00.000000000', '2012-09-19T00:00:00.000000000',
#        '2012-03-28T00:00:00.000000000', '2012-08-01T00:00:00.000000000',
#        '2012-05-09T00:00:00.000000000', '2012-08-08T00:00:00.000000000',
#        '2012-01-18T00:00:00.000000000', '2012-04-18T00:00:00.000000000',
#        '2012-03-21T00:00:00.000000000', '2012-01-11T00:00:00.000000000',
#        '2012-05-30T00:00:00.000000000', '2012-02-08T00:00:00.000000000',
# ...

# %%
x
# Out:
#       year rank                               title  total_sales     id  \
# 0     2012   64               Niko le petit Renne 2       787427  13130
# 1     2010  120                   Fantastic Mr. Fox       357881  10633
# 2     2014  103                                 Her       448841  13728
# 3     2010  145           AO, le dernier Néandertal       248610  11312
# 4     2012  150                  Le Fils de l'autre       251239  12635
# ...    ...  ...                                 ...          ...    ...
# 3954  2017   18                          La La Land      2746019  16448
# 3955  2017   17                              Cars 3      2766647  16452
# 3956  2017   16  La Planète des Singes - Suprématie      2883962  15748
# 3957  2017   15                  Le Sens de la fête      3020694  17386
# 3958  2017    7                    Fast & Furious 8      3838447  15184
#
#      release_date  max_theaters_used  first_day_sales  first_weekend_sales  \
# ...

# %%
x.isnull().sum()
# Out:
# year                     0
# rank                     0
# title                    0
# total_sales              0
# id                       0
# release_date             0
# max_theaters_used        0
# first_day_sales        152
# first_weekend_sales    174
# first_week_sales         0
# dtype: int64

# %%
x['weekday'] = x['release_date'].dt.day_name()

# %%
x['day'] = x['release_date'].dt.day

# %%
x['month'] = x['release_date'].dt.month

# %%
x.head(5)
# Out:
#    year rank                      title  total_sales     id release_date  \
# 0  2012   64      Niko le petit Renne 2       787427  13130   2012-11-28
# 1  2010  120          Fantastic Mr. Fox       357881  10633   2010-02-17
# 2  2014  103                        Her       448841  13728   2014-03-19
# 3  2010  145  AO, le dernier Néandertal       248610  11312   2010-09-29
# 4  2012  150         Le Fils de l'autre       251239  12635   2012-04-04
#
#    max_theaters_used  first_day_sales  first_weekend_sales  first_week_sales  \
# 0                719          25822.0              94340.0            114702
# 1                163          20088.0              95396.0            128167
# 2                273          21692.0             125094.0            158100
# 3                359          23458.0             115903.0            134591
# 4                159          10143.0              73000.0             88017
#
#      weekday  day  month
# 0  Wednesday   28     11
# ...

# %%
x['day'].value_counts()
# Out:
# 6     161
# 13    143
# 4     142
# 27    140
# 20    139
# 16    138
# 14    135
# 25    134
# 10    133
# 7     133
# 11    133
# 8     133
# 28    132
# 21    132
# 9     132
# 3     131
# 17    131
# 30    128
# 23    128
# 18    128
# 22    125
# 2     122
# 19    121
# 12    120
# 26    119
# 1     119
# 24    119
# 5     119
# 15    118
# 29    103
# 31     68
# Name: day, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(x.day, bins = 7,  rwidth = .8, color = '#AA6666', alpha= .4)
plt.xlabel('day of week')
plt.ylabel('Frequency')
plt.title('Frequency of release')
# Out:
# Text(0.5, 1.0, 'Frequency of release')

# %%
a = x.day
plt.hist(a, bins=30, rwidth = .8, range = (0.5, 30.5))
plt.gca().set(title='Release by DoM',xlabel='date of the month' ,ylabel='Frequency')
# Out:
# [Text(0.5, 1.0, 'Release by DoM'),
#  Text(0.5, 0, 'date of the month'),
#  Text(0, 0.5, 'Frequency')]

# %%
plt.hist(x.month, bins = 24, range = (1, 13))
plt.xlabel('month')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x['title'].value_counts().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of Niko le petit Renne 2              1
# La Reine des neiges                1
# CloClo                             1
# Project X (2012)                   1
# Un bonheur n'arrive jamais seul    1
#                                   ..
# Chala, une enfance cubaine         1
# Desierto                           1
# Un traître idéal                   1
# Eternité                           1
# Fast & Furious 8                   1
# Name: title, Length: 3959, dtype: int64>

# %%
x.columns
# Out:
# Index(['year', 'rank', 'title', 'total_sales', 'id', 'release_date',
#        'max_theaters_used', 'first_day_sales', 'first_weekend_sales',
#        'first_week_sales', 'weekday', 'day', 'month'],
#       dtype='object')

# %%
x["rank"].isnull().sum()
# Out:
# 0

# %%
x["id"].isnull().sum()
# Out:
# 0

# %%
x['rank'].value_counts().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of H.C.    442
# 64       10
# 115      10
# 117      10
# 118      10
#        ...
# 375       2
# 377       2
# 385       1
# 387       1
# 386       1
# Name: rank, Length: 388, dtype: int64>

# %%
x["global_rank"] = x["total_sales"].rank(ascending=0,method='max')

# %%
(x.sort_values(by=['global_rank'], ascending=False))
# Out:
#       year  rank                                 title  total_sales     id  \
# 1610  2013  H.C.                             Ram-Leela           35  13886
# 3325  2019  H.C.                    Salauds de pauvres           50  19397
# 1611  2013  H.C.                #Le Magicien d'Oz (3D)          121  13754
# 2131  2011  H.C.              Bienvenue à Cedar Rapids          124  11988
# 423   2014  H.C.                         Dom Hemingway          149  13811
# ...    ...   ...                                   ...          ...    ...
# 2689  2011     2                       Rien à déclarer      8150825  11191
# 3513  2019     1                    Le Roi Lion (2019)     10017995  17528
# 2570  2015     1      Star Wars: Le Réveil de la Force     10507561  13345
# 2600  2014     1  Qu'est-ce qu'on a fait au Bon Dieu ?     12366033  14040
# 2690  2011     1                          Intouchables     19490688  12364
#
# ...

# %%
x.dtypes
# Out:
# year                            int64
# rank                           object
# title                          object
# total_sales                     int64
# id                              int64
# release_date           datetime64[ns]
# max_theaters_used               int64
# first_day_sales               float64
# first_weekend_sales           float64
# first_week_sales                int64
# weekday                        object
# day                             int64
# month                           int64
# global_rank                   float64
# dtype: object

# %%
x['global_rank'] = x['global_rank'].astype(int)

# %%
x.drop(['rank'], axis=1, inplace=True)

# %%
(x.sort_values(by=['global_rank'], ascending=True))
# Out:
#       year                                 title  total_sales     id  \
# 2690  2011                          Intouchables     19490688  12364
# 2600  2014  Qu'est-ce qu'on a fait au Bon Dieu ?     12366033  14040
# 2570  2015      Star Wars: Le Réveil de la Force     10507561  13345
# 3513  2019                    Le Roi Lion (2019)     10017995  17528
# 2689  2011                       Rien à déclarer      8150825  11191
# ...    ...                                   ...          ...    ...
# 423   2014                         Dom Hemingway          149  13811
# 2131  2011              Bienvenue à Cedar Rapids          124  11988
# 1611  2013                #Le Magicien d'Oz (3D)          121  13754
# 3325  2019                    Salauds de pauvres           50  19397
# 1610  2013                             Ram-Leela           35  13886
#
#      release_date  max_theaters_used  first_day_sales  first_weekend_sales  \
# ...

# %%
x.set_index(['global_rank'], inplace = True)

# %%
x=x.sort_index(ascending=True)

# %%
x.drop(['weekday'], axis=1, inplace=True)

# %%
first_column = x.pop('year')

# %%
x.insert(10, 'year', first_column)

# %%
second_column = x.pop('total_sales')

# %%
x.insert(7,'total_sales', second_column)

# %%
x.head(5)
# Out:
#                                             title     id release_date  \
# global_rank
# 1                                    Intouchables  12364   2011-11-02
# 2            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16
# 3                Star Wars: Le Réveil de la Force  13345   2015-12-16
# 4                              Le Roi Lion (2019)  17528   2019-07-17
# 5                                 Rien à déclarer  11191   2011-02-02
#
#              max_theaters_used  first_day_sales  first_weekend_sales  \
# global_rank
# 1                          898         191342.0            1653303.0
# 2                          821         200723.0            1150076.0
# 3                         1093         619020.0            2705096.0
# 4                          820         630478.0            2559370.0
# 5                         1036         301089.0            2244226.0
#
#              first_week_sales  total_sales  day  month  year
# global_rank
# ...

# %%
third_column = x.pop('day')
fourth_column = x.pop('month')
fifth_column = x.pop('year')

# %%
x.insert(3, 'day', third_column)
x.insert(4, 'month', fourth_column)
x.insert(5,'year', fifth_column)

# %%
x.head(5)
# Out:
#                                             title     id release_date  day  \
# global_rank
# 1                                    Intouchables  12364   2011-11-02    2
# 2            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16   16
# 3                Star Wars: Le Réveil de la Force  13345   2015-12-16   16
# 4                              Le Roi Lion (2019)  17528   2019-07-17   17
# 5                                 Rien à déclarer  11191   2011-02-02    2
#
#              month  year  max_theaters_used  first_day_sales  \
# global_rank
# 1               11  2011                898         191342.0
# 2                4  2014                821         200723.0
# 3               12  2015               1093         619020.0
# 4                7  2019                820         630478.0
# 5                2  2011               1036         301089.0
#
#              first_weekend_sales  first_week_sales  total_sales
# global_rank
# ...

# %%
### Missing values / percentage
x.isnull().sum() / x.shape[0] * 100
# Out:
# title                  0.000000
# id                     0.000000
# release_date           0.000000
# day                    0.000000
# month                  0.000000
# year                   0.000000
# max_theaters_used      0.000000
# first_day_sales        3.839353
# first_weekend_sales    4.395049
# first_week_sales       0.000000
# total_sales            0.000000
# dtype: float64

# %%
import seaborn as sns
ax = sns.boxplot(x=x["total_sales"])

# %%
corrMatrix = x.corr()
corrMatrix
# Out:
#                            id       day     month      year  \
# id                   1.000000  0.014575  0.067193  0.945865
# day                  0.014575  1.000000  0.020520  0.002717
# month                0.067193  0.020520  1.000000 -0.020711
# year                 0.945865  0.002717 -0.020711  1.000000
# max_theaters_used   -0.039107  0.017960  0.032401  0.055254
# first_day_sales     -0.088214  0.017011  0.016456  0.005061
# first_weekend_sales -0.120013  0.022457 -0.002588 -0.022869
# first_week_sales    -0.121635  0.026278 -0.002731 -0.025196
# total_sales         -0.104696  0.006267  0.022615 -0.023988
#
#                      max_theaters_used  first_day_sales  first_weekend_sales  \
# id                           -0.039107        -0.088214            -0.120013
# day                           0.017960         0.017011             0.022457
# month                         0.032401         0.016456            -0.002588
# ...

# %%
sns.heatmap(corrMatrix, annot = True, cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
x['viewers_by_theaters'] = (x['total_sales'] // x['max_theaters_used'])

# %%
x['viewers_by_theaters']
# Out:
# global_rank
# 1       21704.0
# 2       15062.0
# 3        9613.0
# 4       12217.0
# 5        7867.0
#          ...
# 3955       49.0
# 3956       11.0
# 3957      121.0
# 3958        inf
# 3959       35.0
# Name: viewers_by_theaters, Length: 3959, dtype: float64

# %%
x
# Out:
#                                             title     id release_date  day  \
# global_rank
# 1                                    Intouchables  12364   2011-11-02    2
# 2            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16   16
# 3                Star Wars: Le Réveil de la Force  13345   2015-12-16   16
# 4                              Le Roi Lion (2019)  17528   2019-07-17   17
# 5                                 Rien à déclarer  11191   2011-02-02    2
# ...                                           ...    ...          ...  ...
# 3955                                Dom Hemingway  13811   2014-06-04    4
# 3956                     Bienvenue à Cedar Rapids  11988   2011-06-15   15
# 3957                       #Le Magicien d'Oz (3D)  13754   2013-10-02    2
# 3958                           Salauds de pauvres  19397   2019-06-05    5
# 3959                                    Ram-Leela  13886   2013-12-04    4
#
# ...

# %%
x.loc[x['max_theaters_used']==0]
# Out:
#                                                       title     id  \
# global_rank
# 1700                                Balade entre les tombes  14480
# 2601         Ptérodactyles 3D : Dans le ciel des dinosaures  12904
# 2850                             Le dernier voyage de Tanya  11839
# 2921                                                 Difret  15358
# 3186                                    M et le 3ème secret  15334
# 3386                                       Le Piano Magique  14182
# 3427             Le Ruisseau, le pré vert et le doux visage  16799
# 3625                                                Torpedo  12737
# 3726                                                Dhoom 3  13964
# 3852                                        Bajirao Mastani  15663
# 3868                        Billy Elliot - The Musical Live  14601
# 3925                                         Recep Ivedik 6  19806
# 3958                                     Salauds de pauvres  19397
#
# ...

# %%
x.describe()
# Out:
#                  id          day        month         year  max_theaters_used  \
# count   3959.000000  3959.000000  3959.000000  3959.000000        3959.000000
# mean   15024.960849    15.613791     6.511745  2014.638040         238.967921
# std     2574.012114     8.750290     3.512743     2.843053         213.411191
# min      299.000000     1.000000     1.000000  2010.000000           0.000000
# 25%    12856.500000     8.000000     3.000000  2012.000000          65.000000
# 50%    14941.000000    16.000000     7.000000  2015.000000         178.000000
# 75%    17226.500000    23.000000    10.000000  2017.000000         353.500000
# max    21624.000000    31.000000    12.000000  2019.000000        1205.000000
#
#        first_day_sales  first_weekend_sales  first_week_sales   total_sales  \
# count      3807.000000         3.785000e+03      3.959000e+03  3.959000e+03
# mean      33386.873916         1.525431e+05      1.841008e+05  4.917572e+05
# ...

# %%
x.loc[x['max_theaters_used']==166]
# Out:
#                                         title     id release_date  day  month  \
# global_rank
# 1343                               Sinister 2  15011   2015-08-19   19      8
# 1660                                 Une nuit  12476   2012-01-04    4      1
# 2484                         Une fille facile  19593   2019-08-28   28      8
# 2791         Des nouvelles de la planète Mars  15733   2016-03-09    9      3
#
#              year  max_theaters_used  first_day_sales  first_weekend_sales  \
# global_rank
# 1343         2015                166          25612.0              95527.0
# 1660         2012                166          16277.0             113395.0
# 2484         2019                166           8073.0              35508.0
# 2791         2016                166           5881.0              32016.0
#
#              first_week_sales  total_sales  viewers_by_theaters
# global_rank
# 1343                   128072       304198               1832.0
# ...

# %%
x
# Out:
#                                             title     id release_date  day  \
# global_rank
# 1                                    Intouchables  12364   2011-11-02    2
# 2            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16   16
# 3                Star Wars: Le Réveil de la Force  13345   2015-12-16   16
# 4                              Le Roi Lion (2019)  17528   2019-07-17   17
# 5                                 Rien à déclarer  11191   2011-02-02    2
# ...                                           ...    ...          ...  ...
# 3955                                Dom Hemingway  13811   2014-06-04    4
# 3956                     Bienvenue à Cedar Rapids  11988   2011-06-15   15
# 3957                       #Le Magicien d'Oz (3D)  13754   2013-10-02    2
# 3958                           Salauds de pauvres  19397   2019-06-05    5
# 3959                                    Ram-Leela  13886   2013-12-04    4
#
# ...

# %%
x['viewers_by_theaters'] = (x['total_sales'] // x['max_theaters_used'])

# %%
x
# Out:
#                                             title     id release_date  day  \
# global_rank
# 1                                    Intouchables  12364   2011-11-02    2
# 2            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16   16
# 3                Star Wars: Le Réveil de la Force  13345   2015-12-16   16
# 4                              Le Roi Lion (2019)  17528   2019-07-17   17
# 5                                 Rien à déclarer  11191   2011-02-02    2
# ...                                           ...    ...          ...  ...
# 3955                                Dom Hemingway  13811   2014-06-04    4
# 3956                     Bienvenue à Cedar Rapids  11988   2011-06-15   15
# 3957                       #Le Magicien d'Oz (3D)  13754   2013-10-02    2
# 3958                           Salauds de pauvres  19397   2019-06-05    5
# 3959                                    Ram-Leela  13886   2013-12-04    4
#
# ...

# %%
x.to_csv(r'/Users/helmichaaba/Downloads/box_office_2010s.csv')
