# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_json('/Users/helmichaaba/Downloads/french-box-office-23nov2020.json')

# %%
df
# Out:
#       year rank                               title  total_sales     id  \
# 0     2012   64               Niko le petit Renne 2       787427  13130
# 1     2007   91       J'veux pas que tu t'en ailles       423200     55
# 2     2010  120                   Fantastic Mr. Fox       357881  10633
# 3     2014  103                                 Her       448841  13728
# 4     2000  150            La Vache et le président       158541   2542
# ...    ...  ...                                 ...          ...    ...
# 7527  2017   18                          La La Land      2746019  16448
# 7528  2017   17                              Cars 3      2766647  16452
# 7529  2017   16  La Planète des Singes - Suprématie      2883962  15748
# 7530  2017   15                  Le Sens de la fête      3020694  17386
# 7531  2017    7                    Fast & Furious 8      3838447  15184
#
#      release_date  max_theaters_used  first_screening_sales  first_day_sales  \
# 0      2012-11-28                719                    NaN          25822.0
# 1      2007-04-25                266                    NaN          21978.0
# 2      2010-02-17                163                    NaN          20088.0
# 3      2014-03-19                273                    NaN          21692.0
# 4      2000-06-28                203                    NaN              NaN
# ...           ...                ...                    ...              ...
# 7527   2017-01-25                844                    NaN         108840.0
# 7528   2017-08-02                716                    NaN         323166.0
# 7529   2017-08-02                769                    NaN         270056.0
# 7530   2017-10-04                733                    NaN         110125.0
# 7531   2017-04-12                713                    NaN         312235.0
#
#       first_weekend_sales  first_week_sales
# 0                 94340.0            114702
# 1                105837.0            154632
# 2                 95396.0            128167
# 3                125094.0            158100
# 4                     NaN             42083
# ...                   ...               ...
# 7527             605105.0            754534
# 7528             836742.0            950353
# 7529             871638.0           1016520
# 7530             657768.0            808544
# 7531            1410345.0           1861108
#
# [7532 rows x 11 columns]

# %%
df.shape
# Out:
# (7532, 11)

# %%
df.describe()
# Out:
#               year   total_sales            id  max_theaters_used  \
# count  7532.000000  7.532000e+03   7532.000000        7532.000000
# mean   2010.300451  5.016893e+05  10466.278943         229.108736
# std       5.891407  1.029735e+06   6612.603981         212.061469
# min    2000.000000  3.500000e+01      2.000000           0.000000
# 25%    2005.000000  4.918125e+04   2256.750000          59.000000
# 50%    2011.000000  1.505295e+05  12172.000000         166.000000
# 75%    2015.000000  4.824072e+05  15718.000000         344.000000
# max    2020.000000  2.048930e+07  21624.000000        1205.000000
#
#        first_screening_sales  first_day_sales  first_weekend_sales  \
# count             112.000000      6712.000000         6.130000e+03
# mean            22549.151786     34318.129172         1.695713e+05
# std             49629.769844     69423.985019         2.970910e+05
# min                 1.000000         1.000000         2.200000e+01
# 25%                30.000000      3575.500000         1.956400e+04
# 50%              2242.000000     11906.000000         6.432200e+04
# 75%             15026.500000     33764.500000         1.870452e+05
# max            235107.000000    850297.000000         3.586497e+06
#
#        first_week_sales
# count      7.532000e+03
# mean       1.830777e+05
# std        3.351055e+05
# min        0.000000e+00
# 25%        2.028100e+04
# 50%        6.733250e+04
# 75%        1.966005e+05
# max        4.378720e+06

# %%
df.dtypes
# Out:
# year                       int64
# rank                      object
# title                     object
# total_sales                int64
# id                         int64
# release_date              object
# max_theaters_used          int64
# first_screening_sales    float64
# first_day_sales          float64
# first_weekend_sales      float64
# first_week_sales           int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# year                        0
# rank                        0
# title                       0
# total_sales                 0
# id                          0
# release_date                0
# max_theaters_used           0
# first_screening_sales    7420
# first_day_sales           820
# first_weekend_sales      1402
# first_week_sales            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['year', 'rank', 'title', 'total_sales', 'id', 'release_date',
#        'max_theaters_used', 'first_screening_sales', 'first_day_sales',
#        'first_weekend_sales', 'first_week_sales'],
#       dtype='object')

# %%
df.drop(['first_screening_sales'], axis=1, inplace=True)

# %%
df
# Out:
#       year rank                               title  total_sales     id  \
# 0     2012   64               Niko le petit Renne 2       787427  13130
# 1     2007   91       J'veux pas que tu t'en ailles       423200     55
# 2     2010  120                   Fantastic Mr. Fox       357881  10633
# 3     2014  103                                 Her       448841  13728
# 4     2000  150            La Vache et le président       158541   2542
# ...    ...  ...                                 ...          ...    ...
# 7527  2017   18                          La La Land      2746019  16448
# 7528  2017   17                              Cars 3      2766647  16452
# 7529  2017   16  La Planète des Singes - Suprématie      2883962  15748
# 7530  2017   15                  Le Sens de la fête      3020694  17386
# 7531  2017    7                    Fast & Furious 8      3838447  15184
#
#      release_date  max_theaters_used  first_day_sales  first_weekend_sales  \
# 0      2012-11-28                719          25822.0              94340.0
# 1      2007-04-25                266          21978.0             105837.0
# 2      2010-02-17                163          20088.0              95396.0
# 3      2014-03-19                273          21692.0             125094.0
# 4      2000-06-28                203              NaN                  NaN
# ...           ...                ...              ...                  ...
# 7527   2017-01-25                844         108840.0             605105.0
# 7528   2017-08-02                716         323166.0             836742.0
# 7529   2017-08-02                769         270056.0             871638.0
# 7530   2017-10-04                733         110125.0             657768.0
# 7531   2017-04-12                713         312235.0            1410345.0
#
#       first_week_sales
# 0               114702
# 1               154632
# 2               128167
# 3               158100
# 4                42083
# ...                ...
# 7527            754534
# 7528            950353
# 7529           1016520
# 7530            808544
# 7531           1861108
#
# [7532 rows x 10 columns]

# %%
df.dtypes
# Out:
# year                     int64
# rank                    object
# title                   object
# total_sales              int64
# id                       int64
# release_date            object
# max_theaters_used        int64
# first_day_sales        float64
# first_weekend_sales    float64
# first_week_sales         int64
# dtype: object

# %%
x=df.loc[df['release_date']!="2000-00-00"]

# %%
x
# Out:
#       year rank                               title  total_sales     id  \
# 0     2012   64               Niko le petit Renne 2       787427  13130
# 1     2007   91       J'veux pas que tu t'en ailles       423200     55
# 2     2010  120                   Fantastic Mr. Fox       357881  10633
# 3     2014  103                                 Her       448841  13728
# 4     2000  150            La Vache et le président       158541   2542
# ...    ...  ...                                 ...          ...    ...
# 7527  2017   18                          La La Land      2746019  16448
# 7528  2017   17                              Cars 3      2766647  16452
# 7529  2017   16  La Planète des Singes - Suprématie      2883962  15748
# 7530  2017   15                  Le Sens de la fête      3020694  17386
# 7531  2017    7                    Fast & Furious 8      3838447  15184
#
#      release_date  max_theaters_used  first_day_sales  first_weekend_sales  \
# 0      2012-11-28                719          25822.0              94340.0
# 1      2007-04-25                266          21978.0             105837.0
# 2      2010-02-17                163          20088.0              95396.0
# 3      2014-03-19                273          21692.0             125094.0
# 4      2000-06-28                203              NaN                  NaN
# ...           ...                ...              ...                  ...
# 7527   2017-01-25                844         108840.0             605105.0
# 7528   2017-08-02                716         323166.0             836742.0
# 7529   2017-08-02                769         270056.0             871638.0
# 7530   2017-10-04                733         110125.0             657768.0
# 7531   2017-04-12                713         312235.0            1410345.0
#
#       first_week_sales
# 0               114702
# 1               154632
# 2               128167
# 3               158100
# 4                42083
# ...                ...
# 7527            754534
# 7528            950353
# 7529           1016520
# 7530            808544
# 7531           1861108
#
# [7531 rows x 10 columns]

# %%
x['release_date']= pd.to_datetime(x['release_date'],format = '%Y-%m-%d')

# %%
x.dtypes
# Out:
# year                            int64
# rank                           object
# title                          object
# total_sales                     int64
# id                              int64
# release_date           datetime64[ns]
# max_theaters_used               int64
# first_day_sales               float64
# first_weekend_sales           float64
# first_week_sales                int64
# dtype: object

# %%
x['release_date'].unique()
# Out:
# array(['2012-11-28T00:00:00.000000000', '2007-04-25T00:00:00.000000000',
#        '2010-02-17T00:00:00.000000000', ...,
#        '2018-11-29T00:00:00.000000000', '2018-01-25T00:00:00.000000000',
#        '2018-05-18T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
x
# Out:
#       year rank                               title  total_sales     id  \
# 0     2012   64               Niko le petit Renne 2       787427  13130
# 1     2007   91       J'veux pas que tu t'en ailles       423200     55
# 2     2010  120                   Fantastic Mr. Fox       357881  10633
# 3     2014  103                                 Her       448841  13728
# 4     2000  150            La Vache et le président       158541   2542
# ...    ...  ...                                 ...          ...    ...
# 7527  2017   18                          La La Land      2746019  16448
# 7528  2017   17                              Cars 3      2766647  16452
# 7529  2017   16  La Planète des Singes - Suprématie      2883962  15748
# 7530  2017   15                  Le Sens de la fête      3020694  17386
# 7531  2017    7                    Fast & Furious 8      3838447  15184
#
#      release_date  max_theaters_used  first_day_sales  first_weekend_sales  \
# 0      2012-11-28                719          25822.0              94340.0
# 1      2007-04-25                266          21978.0             105837.0
# 2      2010-02-17                163          20088.0              95396.0
# 3      2014-03-19                273          21692.0             125094.0
# 4      2000-06-28                203              NaN                  NaN
# ...           ...                ...              ...                  ...
# 7527   2017-01-25                844         108840.0             605105.0
# 7528   2017-08-02                716         323166.0             836742.0
# 7529   2017-08-02                769         270056.0             871638.0
# 7530   2017-10-04                733         110125.0             657768.0
# 7531   2017-04-12                713         312235.0            1410345.0
#
#       first_week_sales
# 0               114702
# 1               154632
# 2               128167
# 3               158100
# 4                42083
# ...                ...
# 7527            754534
# 7528            950353
# 7529           1016520
# 7530            808544
# 7531           1861108
#
# [7531 rows x 10 columns]

# %%
x.isnull().sum()
# Out:
# year                      0
# rank                      0
# title                     0
# total_sales               0
# id                        0
# release_date              0
# max_theaters_used         0
# first_day_sales         819
# first_weekend_sales    1401
# first_week_sales          0
# dtype: int64

# %%
x['weekday'] = x['release_date'].dt.day_name()

# %%
x['day'] = x['release_date'].dt.day

# %%
x['month'] = x['release_date'].dt.month

# %%
x.head(5)
# Out:
#    year rank                          title  total_sales     id release_date  \
# 0  2012   64          Niko le petit Renne 2       787427  13130   2012-11-28
# 1  2007   91  J'veux pas que tu t'en ailles       423200     55   2007-04-25
# 2  2010  120              Fantastic Mr. Fox       357881  10633   2010-02-17
# 3  2014  103                            Her       448841  13728   2014-03-19
# 4  2000  150       La Vache et le président       158541   2542   2000-06-28
#
#    max_theaters_used  first_day_sales  first_weekend_sales  first_week_sales  \
# 0                719          25822.0              94340.0            114702
# 1                266          21978.0             105837.0            154632
# 2                163          20088.0              95396.0            128167
# 3                273          21692.0             125094.0            158100
# 4                203              NaN                  NaN             42083
#
#      weekday  day  month
# 0  Wednesday   28     11
# 1  Wednesday   25      4
# 2  Wednesday   17      2
# 3  Wednesday   19      3
# 4  Wednesday   28      6

# %%
x['day'].value_counts()
# Out:
# 5     267
# 6     265
# 4     265
# 12    261
# 19    260
# 16    259
# 11    259
# 9     257
# 28    257
# 7     256
# 14    255
# 22    254
# 21    254
# 26    252
# 23    250
# 8     247
# 13    247
# 25    246
# 30    244
# 10    244
# 17    242
# 18    242
# 20    241
# 15    239
# 1     233
# 27    228
# 3     225
# 24    223
# 2     222
# 29    208
# 31    129
# Name: day, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(x.day, bins = 7,  rwidth = .8, color = '#AA6666', alpha= .4)
plt.xlabel('day of week')
plt.ylabel('Frequency')
plt.title('Frequency of release')
# Out:
# Text(0.5, 1.0, 'Frequency of release')

# %%
a = x.day
plt.hist(a, bins=30, rwidth = .8, range = (0.5, 30.5))
plt.gca().set(title='Release by DoM',xlabel='date of the month' ,ylabel='Frequency')
# Out:
# [Text(0.5, 1.0, 'Release by DoM'),
#  Text(0.5, 0, 'date of the month'),
#  Text(0, 0.5, 'Frequency')]

# %%
plt.hist(x.month, bins = 24, range = (1, 13))
plt.xlabel('month')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x['title'].value_counts().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of Niko le petit Renne 2    1
# The Hole                 1
# The One                  1
# The Pledge               1
# Sexy Boys                1
#                         ..
# Crimson Peak             1
# La Belle saison          1
# Unfriended               1
# Au-delà des montagnes    1
# Fast & Furious 8         1
# Name: title, Length: 7531, dtype: int64>

# %%
x.columns
# Out:
# Index(['year', 'rank', 'title', 'total_sales', 'id', 'release_date',
#        'max_theaters_used', 'first_day_sales', 'first_weekend_sales',
#        'first_week_sales', 'weekday', 'day', 'month'],
#       dtype='object')

# %%
x["rank"].isnull().sum()
# Out:
# 0

# %%
x["id"].isnull().sum()
# Out:
# 0

# %%
x['rank'].value_counts().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of H.C.    1011
# 64        21
# 110       21
# 112       21
# 113       21
#         ...
# 375        2
# 378        2
# 385        1
# 387        1
# 386        1
# Name: rank, Length: 388, dtype: int64>

# %%
x["global_rank"] = x["total_sales"].rank(ascending=0,method='max')

# %%
(x.sort_values(by=['global_rank'], ascending=False))
# Out:
#       year  rank                                 title  total_sales     id  \
# 91    2009  H.C.                        The Answer Man           35  10893
# 3554  2013  H.C.                             Ram-Leela           35  13886
# 1600  2004  H.C.                            Soul Plane           41   1341
# 6898  2019  H.C.                    Salauds de pauvres           50  19397
# 72    2005  H.C.                               Madison           57    997
# ...    ...   ...                                   ...          ...    ...
# 5674  2014     1  Qu'est-ce qu'on a fait au Bon Dieu ?     12366033  14040
# 6033  2002     1  Astérix et Obélix: Mission Cléopatre     14559509   1741
# 5823  2009     1                                Avatar     14677888   9975
# 5764  2011     1                          Intouchables     19490688  12364
# 5853  2008     1             Bienvenue chez les Ch'tis     20489303  10042
#
#      release_date  max_theaters_used  first_day_sales  first_weekend_sales  \
# 91     2009-12-30                  1              1.0                 22.0
# 3554   2013-12-04                  1              NaN                  NaN
# 1600   2004-11-17                  1              4.0                 30.0
# 6898   2019-06-05                  0              NaN                  NaN
# 72     2005-09-28                  1              8.0                  NaN
# ...           ...                ...              ...                  ...
# 5674   2014-04-16                821         200723.0            1150076.0
# 6033   2002-01-30                954         629148.0            2960046.0
# 5823   2009-12-16                730         320934.0            1806542.0
# 5764   2011-11-02                898         191342.0            1653303.0
# 5853   2008-02-27                906         558359.0            3586497.0
#
#       first_week_sales    weekday  day  month  global_rank
# 91                  35  Wednesday   30     12       7531.0
# 3554                 0  Wednesday    4     12       7531.0
# 1600                41  Wednesday   17     11       7529.0
# 6898                 0  Wednesday    5      6       7528.0
# 72                  57  Wednesday   28      9       7527.0
# ...                ...        ...  ...    ...          ...
# 5674           1680249  Wednesday   16      4          5.0
# 6033           3685097  Wednesday   30      1          4.0
# 5823           2648596  Wednesday   16     12          3.0
# 5764           2126545  Wednesday    2     11          2.0
# 5853           4378720  Wednesday   27      2          1.0
#
# [7531 rows x 14 columns]

# %%
x.dtypes
# Out:
# year                            int64
# rank                           object
# title                          object
# total_sales                     int64
# id                              int64
# release_date           datetime64[ns]
# max_theaters_used               int64
# first_day_sales               float64
# first_weekend_sales           float64
# first_week_sales                int64
# weekday                        object
# day                             int64
# month                           int64
# global_rank                   float64
# dtype: object

# %%
x['global_rank'] = x['global_rank'].astype(int)

# %%
x.drop(['rank'], axis=1, inplace=True)

# %%
(x.sort_values(by=['global_rank'], ascending=True))
# Out:
#       year                                 title  total_sales     id  \
# 5853  2008             Bienvenue chez les Ch'tis     20489303  10042
# 5764  2011                          Intouchables     19490688  12364
# 5823  2009                                Avatar     14677888   9975
# 6033  2002  Astérix et Obélix: Mission Cléopatre     14559509   1741
# 5674  2014  Qu'est-ce qu'on a fait au Bon Dieu ?     12366033  14040
# ...    ...                                   ...          ...    ...
# 72    2005                               Madison           57    997
# 6898  2019                    Salauds de pauvres           50  19397
# 1600  2004                            Soul Plane           41   1341
# 91    2009                        The Answer Man           35  10893
# 3554  2013                             Ram-Leela           35  13886
#
#      release_date  max_theaters_used  first_day_sales  first_weekend_sales  \
# 5853   2008-02-27                906         558359.0            3586497.0
# 5764   2011-11-02                898         191342.0            1653303.0
# 5823   2009-12-16                730         320934.0            1806542.0
# 6033   2002-01-30                954         629148.0            2960046.0
# 5674   2014-04-16                821         200723.0            1150076.0
# ...           ...                ...              ...                  ...
# 72     2005-09-28                  1              8.0                  NaN
# 6898   2019-06-05                  0              NaN                  NaN
# 1600   2004-11-17                  1              4.0                 30.0
# 91     2009-12-30                  1              1.0                 22.0
# 3554   2013-12-04                  1              NaN                  NaN
#
#       first_week_sales    weekday  day  month  global_rank
# 5853           4378720  Wednesday   27      2            1
# 5764           2126545  Wednesday    2     11            2
# 5823           2648596  Wednesday   16     12            3
# 6033           3685097  Wednesday   30      1            4
# 5674           1680249  Wednesday   16      4            5
# ...                ...        ...  ...    ...          ...
# 72                  57  Wednesday   28      9         7527
# 6898                 0  Wednesday    5      6         7528
# 1600                41  Wednesday   17     11         7529
# 91                  35  Wednesday   30     12         7531
# 3554                 0  Wednesday    4     12         7531
#
# [7531 rows x 13 columns]

# %%
x.set_index(['global_rank'], inplace = True)

# %%
x=x.sort_index(ascending=True)

# %%
x.drop(['weekday'], axis=1, inplace=True)

# %%
first_column = x.pop('year')

# %%
x.insert(10, 'year', first_column)

# %%
second_column = x.pop('total_sales')

# %%
x.insert(7,'total_sales', second_column)

# %%
x.head(5)
# Out:
#                                             title     id release_date  \
# global_rank
# 1                       Bienvenue chez les Ch'tis  10042   2008-02-27
# 2                                    Intouchables  12364   2011-11-02
# 3                                          Avatar   9975   2009-12-16
# 4            Astérix et Obélix: Mission Cléopatre   1741   2002-01-30
# 5            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16
#
#              max_theaters_used  first_day_sales  first_weekend_sales  \
# global_rank
# 1                          906         558359.0            3586497.0
# 2                          898         191342.0            1653303.0
# 3                          730         320934.0            1806542.0
# 4                          954         629148.0            2960046.0
# 5                          821         200723.0            1150076.0
#
#              first_week_sales  total_sales  day  month  year
# global_rank
# 1                     4378720     20489303   27      2  2008
# 2                     2126545     19490688    2     11  2011
# 3                     2648596     14677888   16     12  2009
# 4                     3685097     14559509   30      1  2002
# 5                     1680249     12366033   16      4  2014

# %%
third_column = x.pop('day')
fourth_column = x.pop('month')
fifth_column = x.pop('year')

# %%
x.insert(3, 'day', third_column)
x.insert(4, 'month', fourth_column)
x.insert(5,'year', fifth_column)

# %%
x.head(5)
# Out:
#                                             title     id release_date  day  \
# global_rank
# 1                       Bienvenue chez les Ch'tis  10042   2008-02-27   27
# 2                                    Intouchables  12364   2011-11-02    2
# 3                                          Avatar   9975   2009-12-16   16
# 4            Astérix et Obélix: Mission Cléopatre   1741   2002-01-30   30
# 5            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16   16
#
#              month  year  max_theaters_used  first_day_sales  \
# global_rank
# 1                2  2008                906         558359.0
# 2               11  2011                898         191342.0
# 3               12  2009                730         320934.0
# 4                1  2002                954         629148.0
# 5                4  2014                821         200723.0
#
#              first_weekend_sales  first_week_sales  total_sales
# global_rank
# 1                      3586497.0           4378720     20489303
# 2                      1653303.0           2126545     19490688
# 3                      1806542.0           2648596     14677888
# 4                      2960046.0           3685097     14559509
# 5                      1150076.0           1680249     12366033

# %%
### Missing values / percentage
x.isnull().sum() / x.shape[0] * 100
# Out:
# title                   0.000000
# id                      0.000000
# release_date            0.000000
# day                     0.000000
# month                   0.000000
# year                    0.000000
# max_theaters_used       0.000000
# first_day_sales        10.875050
# first_weekend_sales    18.603107
# first_week_sales        0.000000
# total_sales             0.000000
# dtype: float64

# %%
import seaborn as sns
ax = sns.boxplot(x=x["total_sales"])

# %%
corrMatrix = x.corr()
corrMatrix
# Out:
#                            id       day     month      year  \
# id                   1.000000  0.005514  0.014312  0.868898
# day                  0.005514  1.000000  0.017938  0.000951
# month                0.014312  0.017938  1.000000 -0.016290
# year                 0.868898  0.000951 -0.016290  1.000000
# max_theaters_used   -0.012797  0.012753  0.033462  0.100182
# first_day_sales     -0.095739  0.010315  0.011081 -0.040928
# first_weekend_sales -0.189744  0.020919 -0.006174 -0.116221
# first_week_sales    -0.092423  0.021310  0.000251 -0.016421
# total_sales         -0.094561  0.004893  0.012926 -0.032193
#
#                      max_theaters_used  first_day_sales  first_weekend_sales  \
# id                           -0.012797        -0.095739            -0.189744
# day                           0.012753         0.010315             0.020919
# month                         0.033462         0.011081            -0.006174
# year                          0.100182        -0.040928            -0.116221
# max_theaters_used             1.000000         0.721808             0.763399
# first_day_sales               0.721808         1.000000             0.949184
# first_weekend_sales           0.763399         0.949184             1.000000
# first_week_sales              0.765858         0.944686             0.995573
# total_sales                   0.721756         0.857958             0.923030
#
#                      first_week_sales  total_sales
# id                          -0.092423    -0.094561
# day                          0.021310     0.004893
# month                        0.000251     0.012926
# year                        -0.016421    -0.032193
# max_theaters_used            0.765858     0.721756
# first_day_sales              0.944686     0.857958
# first_weekend_sales          0.995573     0.923030
# first_week_sales             1.000000     0.928574
# total_sales                  0.928574     1.000000

# %%
sns.heatmap(corrMatrix, annot = True, cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
x['viewers_by_theaters'] = (x['total_sales'] // x['max_theaters_used'])

# %%
x['viewers_by_theaters']
# Out:
# global_rank
# 1       22615.0
# 2       21704.0
# 3       20106.0
# 4       15261.0
# 5       15062.0
#          ...
# 7527       57.0
# 7528        inf
# 7529       41.0
# 7531       35.0
# 7531       35.0
# Name: viewers_by_theaters, Length: 7531, dtype: float64

# %%
x
# Out:
#                                             title     id release_date  day  \
# global_rank
# 1                       Bienvenue chez les Ch'tis  10042   2008-02-27   27
# 2                                    Intouchables  12364   2011-11-02    2
# 3                                          Avatar   9975   2009-12-16   16
# 4            Astérix et Obélix: Mission Cléopatre   1741   2002-01-30   30
# 5            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16   16
# ...                                           ...    ...          ...  ...
# 7527                                      Madison    997   2005-09-28   28
# 7528                           Salauds de pauvres  19397   2019-06-05    5
# 7529                                   Soul Plane   1341   2004-11-17   17
# 7531                               The Answer Man  10893   2009-12-30   30
# 7531                                    Ram-Leela  13886   2013-12-04    4
#
#              month  year  max_theaters_used  first_day_sales  \
# global_rank
# 1                2  2008                906         558359.0
# 2               11  2011                898         191342.0
# 3               12  2009                730         320934.0
# 4                1  2002                954         629148.0
# 5                4  2014                821         200723.0
# ...            ...   ...                ...              ...
# 7527             9  2005                  1              8.0
# 7528             6  2019                  0              NaN
# 7529            11  2004                  1              4.0
# 7531            12  2009                  1              1.0
# 7531            12  2013                  1              NaN
#
#              first_weekend_sales  first_week_sales  total_sales  \
# global_rank
# 1                      3586497.0           4378720     20489303
# 2                      1653303.0           2126545     19490688
# 3                      1806542.0           2648596     14677888
# 4                      2960046.0           3685097     14559509
# 5                      1150076.0           1680249     12366033
# ...                          ...               ...          ...
# 7527                         NaN                57           57
# 7528                         NaN                 0           50
# 7529                        30.0                41           41
# 7531                        22.0                35           35
# 7531                         NaN                 0           35
#
#              viewers_by_theaters
# global_rank
# 1                        22615.0
# 2                        21704.0
# 3                        20106.0
# 4                        15261.0
# 5                        15062.0
# ...                          ...
# 7527                        57.0
# 7528                         inf
# 7529                        41.0
# 7531                        35.0
# 7531                        35.0
#
# [7531 rows x 12 columns]

# %%
x.loc[x['max_theaters_used']==0]
# Out:
#                                       title     id release_date  day  month  \
# global_rank
# 1303                                Hypnose   2756   2000-05-03    3      5
# 1506                          Fantasia 2000   2454   2000-05-24   24      5
# 1631                                  Vatel   2460   2000-05-10   10      5
# 2261                         Une vie à deux   2788   2000-05-24   24      5
# 2377                       Hurricane Carter   2494   2000-03-22   22      3
# ...                                     ...    ...          ...  ...    ...
# 7508                      Swimming Upstream    995   2005-09-28   28      9
# 7513                            A Guy Thing   1686   2004-08-11   11      8
# 7516         Dickie Roberts: Ex-enfant star   1687   2004-05-12   12      5
# 7523                              Superstar   2985   2000-08-02    2      8
# 7528                     Salauds de pauvres  19397   2019-06-05    5      6
#
#              year  max_theaters_used  first_day_sales  first_weekend_sales  \
# global_rank
# 1303         2000                  0          28094.0             168803.0
# 1506         2000                  0              NaN                  NaN
# 1631         2000                  0              NaN                  NaN
# 2261         2000                  0              NaN                  NaN
# 2377         2000                  0              NaN                  NaN
# ...           ...                ...              ...                  ...
# 7508         2005                  0              NaN                  NaN
# 7513         2004                  0              NaN                  NaN
# 7516         2004                  0              NaN                  NaN
# 7523         2000                  0              NaN                  NaN
# 7528         2019                  0              NaN                  NaN
#
#              first_week_sales  total_sales  viewers_by_theaters
# global_rank
# 1303                   225739       759900                  inf
# 1506                   111237       640488                  inf
# 1631                   177552       578133                  inf
# 2261                   161639       377409                  inf
# 2377                   160514       353216                  inf
# ...                       ...          ...                  ...
# 7508                        0          205                  inf
# 7513                        0          177                  inf
# 7516                        0          162                  inf
# 7523                       75          104                  inf
# 7528                        0           50                  inf
#
# [223 rows x 12 columns]

# %%
x.describe()
# Out:
#                  id          day        month         year  max_theaters_used  \
# count   7531.000000  7531.000000  7531.000000  7531.000000        7531.000000
# mean   10465.568185    15.669632     6.484663  2010.301819         229.139158
# std     6612.755317     8.725609     3.491233     5.890603         212.059112
# min        2.000000     1.000000     1.000000  2000.000000           0.000000
# 25%     2256.500000     8.000000     3.000000  2005.000000          59.000000
# 50%    12169.000000    16.000000     7.000000  2011.000000         166.000000
# 75%    15716.500000    23.000000    10.000000  2015.000000         344.000000
# max    21624.000000    31.000000    12.000000  2020.000000        1205.000000
#
#        first_day_sales  first_weekend_sales  first_week_sales   total_sales  \
# count      6712.000000         6.130000e+03      7.531000e+03  7.531000e+03
# mean      34318.129172         1.695713e+05      1.831020e+05  5.017393e+05
# std       69423.985019         2.970910e+05      3.351211e+05  1.029794e+06
# min           1.000000         2.200000e+01      0.000000e+00  3.500000e+01
# 25%        3575.500000         1.956400e+04      2.028350e+04  4.917350e+04
# 50%       11906.000000         6.432200e+04      6.734200e+04  1.505400e+05
# 75%       33764.500000         1.870452e+05      1.966240e+05  4.825655e+05
# max      850297.000000         3.586497e+06      4.378720e+06  2.048930e+07
#
#        viewers_by_theaters
# count               7531.0
# mean                   inf
# std                    NaN
# min                    3.0
# 25%                  632.0
# 50%                 1152.0
# 75%                 2128.5
# max                    inf

# %%
x.loc[x['max_theaters_used']==166]
# Out:
#                                       title     id release_date  day  month  \
# global_rank
# 1303                                Hypnose   2756   2000-05-03    3      5
# 1506                          Fantasia 2000   2454   2000-05-24   24      5
# 1631                                  Vatel   2460   2000-05-10   10      5
# 1934                    L'Enfer du dimanche   2780   2000-04-12   12      4
# 2261                         Une vie à deux   2788   2000-05-24   24      5
# ...                                     ...    ...          ...  ...    ...
# 7508                      Swimming Upstream    995   2005-09-28   28      9
# 7513                            A Guy Thing   1686   2004-08-11   11      8
# 7516         Dickie Roberts: Ex-enfant star   1687   2004-05-12   12      5
# 7523                              Superstar   2985   2000-08-02    2      8
# 7528                     Salauds de pauvres  19397   2019-06-05    5      6
#
#              year  max_theaters_used  first_day_sales  first_weekend_sales  \
# global_rank
# 1303         2000                166          28094.0             168803.0
# 1506         2000                166              NaN                  NaN
# 1631         2000                166              NaN                  NaN
# 1934         2000                166              NaN                  NaN
# 2261         2000                166              NaN                  NaN
# ...           ...                ...              ...                  ...
# 7508         2005                166              NaN                  NaN
# 7513         2004                166              NaN                  NaN
# 7516         2004                166              NaN                  NaN
# 7523         2000                166              NaN                  NaN
# 7528         2019                166              NaN                  NaN
#
#              first_week_sales  total_sales  viewers_by_theaters
# global_rank
# 1303                   225739       759900                  inf
# 1506                   111237       640488                  inf
# 1631                   177552       578133                  inf
# 1934                   227763       467790               2818.0
# 2261                   161639       377409                  inf
# ...                       ...          ...                  ...
# 7508                        0          205                  inf
# 7513                        0          177                  inf
# 7516                        0          162                  inf
# 7523                       75          104                  inf
# 7528                        0           50                  inf
#
# [230 rows x 12 columns]

# %%
x
# Out:
#                                             title     id release_date  day  \
# global_rank
# 1                       Bienvenue chez les Ch'tis  10042   2008-02-27   27
# 2                                    Intouchables  12364   2011-11-02    2
# 3                                          Avatar   9975   2009-12-16   16
# 4            Astérix et Obélix: Mission Cléopatre   1741   2002-01-30   30
# 5            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16   16
# ...                                           ...    ...          ...  ...
# 7527                                      Madison    997   2005-09-28   28
# 7528                           Salauds de pauvres  19397   2019-06-05    5
# 7529                                   Soul Plane   1341   2004-11-17   17
# 7531                               The Answer Man  10893   2009-12-30   30
# 7531                                    Ram-Leela  13886   2013-12-04    4
#
#              month  year  max_theaters_used  first_day_sales  \
# global_rank
# 1                2  2008                906         558359.0
# 2               11  2011                898         191342.0
# 3               12  2009                730         320934.0
# 4                1  2002                954         629148.0
# 5                4  2014                821         200723.0
# ...            ...   ...                ...              ...
# 7527             9  2005                  1              8.0
# 7528             6  2019                166              NaN
# 7529            11  2004                  1              4.0
# 7531            12  2009                  1              1.0
# 7531            12  2013                  1              NaN
#
#              first_weekend_sales  first_week_sales  total_sales  \
# global_rank
# 1                      3586497.0           4378720     20489303
# 2                      1653303.0           2126545     19490688
# 3                      1806542.0           2648596     14677888
# 4                      2960046.0           3685097     14559509
# 5                      1150076.0           1680249     12366033
# ...                          ...               ...          ...
# 7527                         NaN                57           57
# 7528                         NaN                 0           50
# 7529                        30.0                41           41
# 7531                        22.0                35           35
# 7531                         NaN                 0           35
#
#              viewers_by_theaters
# global_rank
# 1                        22615.0
# 2                        21704.0
# 3                        20106.0
# 4                        15261.0
# 5                        15062.0
# ...                          ...
# 7527                        57.0
# 7528                         inf
# 7529                        41.0
# 7531                        35.0
# 7531                        35.0
#
# [7531 rows x 12 columns]

# %%
x['viewers_by_theaters'] = (x['total_sales'] // x['max_theaters_used'])

# %%
x
# Out:
#                                             title     id release_date  day  \
# global_rank
# 1                       Bienvenue chez les Ch'tis  10042   2008-02-27   27
# 2                                    Intouchables  12364   2011-11-02    2
# 3                                          Avatar   9975   2009-12-16   16
# 4            Astérix et Obélix: Mission Cléopatre   1741   2002-01-30   30
# 5            Qu'est-ce qu'on a fait au Bon Dieu ?  14040   2014-04-16   16
# ...                                           ...    ...          ...  ...
# 7527                                      Madison    997   2005-09-28   28
# 7528                           Salauds de pauvres  19397   2019-06-05    5
# 7529                                   Soul Plane   1341   2004-11-17   17
# 7531                               The Answer Man  10893   2009-12-30   30
# 7531                                    Ram-Leela  13886   2013-12-04    4
#
#              month  year  max_theaters_used  first_day_sales  \
# global_rank
# 1                2  2008                906         558359.0
# 2               11  2011                898         191342.0
# 3               12  2009                730         320934.0
# 4                1  2002                954         629148.0
# 5                4  2014                821         200723.0
# ...            ...   ...                ...              ...
# 7527             9  2005                  1              8.0
# 7528             6  2019                166              NaN
# 7529            11  2004                  1              4.0
# 7531            12  2009                  1              1.0
# 7531            12  2013                  1              NaN
#
#              first_weekend_sales  first_week_sales  total_sales  \
# global_rank
# 1                      3586497.0           4378720     20489303
# 2                      1653303.0           2126545     19490688
# 3                      1806542.0           2648596     14677888
# 4                      2960046.0           3685097     14559509
# 5                      1150076.0           1680249     12366033
# ...                          ...               ...          ...
# 7527                         NaN                57           57
# 7528                         NaN                 0           50
# 7529                        30.0                41           41
# 7531                        22.0                35           35
# 7531                         NaN                 0           35
#
#              viewers_by_theaters
# global_rank
# 1                          22615
# 2                          21704
# 3                          20106
# 4                          15261
# 5                          15062
# ...                          ...
# 7527                          57
# 7528                           0
# 7529                          41
# 7531                          35
# 7531                          35
#
# [7531 rows x 12 columns]
